# %%
import cv2
import imutils
data1 = cv2.imread('image.png')


img_grey = cv2.cvtColor(data1,cv2.COLOR_BGR2GRAY)
#set a thresh
thresh = 100
#get threshold image
ret,data = cv2.threshold(img_grey, thresh, 255, cv2.THRESH_BINARY)

def get_rect(cont):
  list_whitex = []
  list_whitey = []
  cx = 0 
  cy = 0 
  for i in range(data.shape[0]):
    for j in range(data.shape[1]):
      if data[i][j] == 255:
        list_whitex.append(i)
        cx = cx + i
        list_whitey.append(j)
        cy = cy + j
  
  cx = cx/len(list_whitex)
  cy = cy/len(list_whitey)
  minx = min(list_whitex)
  maxx = max(list_whitex)
  miny = min(list_whitey)
  maxy = max(list_whitey)
  height = maxy - miny
  width = maxx - minx
  return cx,cy,height,width

# %%
cnts = imutils.grab_contours(cv2.findContours(data, cv2.RETR_TREE,
	cv2.CHAIN_APPROX_SIMPLE))
output = data1.copy()
# loop over the contours
print(len(cnts))
for c in cnts:
  
  cv2.drawContours(output, [c], -1, (240, 0, 159), 3)
  # print(c)
  cv2_imshow(output)
# Out:
# 2
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F03EF16E250>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F03EF16E250>

# %%
data1 = cv2.imread('image.png')
img_grey = cv2.cvtColor(data1,cv2.COLOR_BGR2GRAY)
#set a thresh
thresh = 10
#get threshold image
ret,data = cv2.threshold(img_grey, thresh, 255, cv2.THRESH_BINARY)

contours, hierarchy = cv2.findContours(data, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

#create an empty image for contours
img_contours = np.zeros(data1.shape)

# draw the contours on the empty image
img = cv2.drawContours(img_contours, contours, -1, (0,255,0), 3)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F03EF6F7C70>
